# %%
# %config IPCompleter.greedy=True
import re

# %%
my_string=re.search('[A-z]','ajjFUT')

# %%
my_string
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
my_string.span()
# Out:
# (0, 1)

# %%
my_string.string
# Out:
# 'ajjFUT'

# %%
my_search=re.search('[A-Z]{3}','DSFJHKJKjfjff')

# %%
my_search
# Out:
# <re.Match object; span=(0, 3), match='DSF'>

# %%
my_search.string
# Out:
# 'DSFJHKJKjfjff'

# %%
op=re.findall('[a-z0-9\.]+@[a-z\.]+','ahmedsheta130@gmail.com')
empty_list=[]
if op!=[] :
    empty_list.append(op)
    
else:
    print('invalid')
print(empty_list)
# Out:
# [['ahmedsheta130@gmail.com']]

# %%
e=re.findall('[a-z0-9\.]+@[a-z\.]+','a.sheta@gmail.com')

# %%
e
# Out:
# ['a.sheta@gmail.com']

# %%
e.append('y.@gmail.com')

# %%
e
# Out:
# ['a.sheta@gmail.com', 'y.@gmail.com']

# %%
e[0]
# Out:
# 'a.sheta@gmail.com'

# %%
my_split=re.split('\s','my name is a Ahmed')

# %%
my_split
# Out:
# ['my', 'name', 'is', 'a', 'Ahmed']

# %%
for counter, word in enumerate(my_split,1) :
    if len(word)==1 :
        continue 
    print(f'the word of { counter} is => {word} ')
# Out:
# the word of 1 is => my
# the word of 2 is => name
# the word of 3 is => is
# the word of 5 is => Ahmed

# %%
print(re.sub('\s','_','My Name Is Ahmed'))
# Out:
# My_Name_Is_Ahmed

# %%
r=re.search('(https?):\/\/(www)?(\w+).(\w+).\/?.+','https://www.elzero.org/category.php?article=105?name=how-to-do')

# %%
r
# Out:
# <re.Match object; span=(0, 62), match='https://www.elzero.org/category.php?article=105?n>

# %%
r.group(3)
# Out:
# 'www'

# %%
print(r.groups())
# Out:
# ('https', None, 'www', 'elzero')

# %%
print('=============================================================================================================== corrrrey')
# Out:
# =============================================================================================================== corrrrey

# %%
import re
text_to_search = '''
abcdefghijklmnopqurtuvwxyz
ABCDEFGHIJKLMNOPQRSTUVWXYZ
1234567890

Ha HaHa

MetaCharacters (Need to be escaped):
. ^ $ * + ? { } [ ] \ | ( )

coreyms.com

321-555-4321
123.555.1234
123*555*1234
800-555-1234
900-555-1234

Mr. Schafer
Mr Smith
Ms Davis
Mrs. Robinson
Mr. T
'''

# %%
pat=re.compile(r'abc')

# %%
m=pat.finditer('hhhuuugkloiyreedghjabc')

# %%
for x in m :
    print(x)
# Out:
# <re.Match object; span=(19, 22), match='abc'>

# %%
r='hhhuuugkloiyreedghjabc'

# %%
r[19:22]
# Out:
# 'abc'

# %%
pattern=re.compile(r'[a-z]+\.\w+')

# %%
results=pattern.finditer(text_to_search)
for match in results :
    print(match)
# Out:
# <re.Match object; span=(142, 153), match='coreyms.com'>

# %%
pattern=re.compile(r'\d{3}-?\.?\*?\d{3}-?\.?\*?\d{4}')
results=pattern.finditer(text_to_search)
for match in results :
    print(match)
# Out:
# <re.Match object; span=(55, 65), match='1234567890'>
# <re.Match object; span=(155, 167), match='321-555-4321'>
# <re.Match object; span=(168, 180), match='123.555.1234'>
# <re.Match object; span=(181, 193), match='123*555*1234'>
# <re.Match object; span=(194, 206), match='800-555-1234'>
# <re.Match object; span=(207, 219), match='900-555-1234'>

# %%
pattern=re.compile(r'\d{3}\.?-?\d{3}[.-]\d{4}')
results=pattern.finditer(text_to_search)
for match in results :
    print(match)
# Out:
# <re.Match object; span=(155, 167), match='321-555-4321'>
# <re.Match object; span=(168, 180), match='123.555.1234'>
# <re.Match object; span=(194, 206), match='800-555-1234'>
# <re.Match object; span=(207, 219), match='900-555-1234'>

# %%
emails = '''
CoreyMSchafer@gmail.com
corey.schafer@university.edu
corey-321-schafer@my-work.net
'''

# %%
pattern=re.compile(r'[Cc]\w{4}.[a-zA-Z0-9]+-?\w+@\w+-?\w*\.\w{3}')

# %%
mat=pattern.finditer(emails)
for mat in mat :
    print(mat)
# Out:
# <re.Match object; span=(1, 24), match='CoreyMSchafer@gmail.com'>
# <re.Match object; span=(25, 53), match='corey.schafer@university.edu'>
# <re.Match object; span=(54, 83), match='corey-321-schafer@my-work.net'>

# %%
urls = '''
https://www.google.com
http://coreyms.com
https://youtube.com
https://www.nasa.gov
'''

pattern = re.compile(r'https?://(www\.)?(\w+)(\.\w+)')

# subbed_urls = pattern.sub(r'\2\3', urls)

# print(subbed_urls)
matches = pattern.finditer(urls)
for match in matches:
   print(match.group(2))
# Out:
# google
# coreyms
# youtube
# nasa

# %%
matches = pattern.findall(urls)
matches
# Out:
# [('www.', 'google', '.com'),
#  ('', 'coreyms', '.com'),
#  ('', 'youtube', '.com'),
#  ('www.', 'nasa', '.gov')]

# %%
f=pattern.sub(r'\2\3',urls)
print(f)
# Out:
# google.com
# coreyms.com
# youtube.com
# nasa.gov
