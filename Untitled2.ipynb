# %%
import numpy as np
from numpy import linalg
def check_invese(arr) :
    if np.linalg.det==0 :
        print("can NOT calculate ther invese")
    else :
        print("can do it")
arr1=np.array([[50,29,33],[30,44,12],[2,3,78]])
check_invese(arr1)
print(f"the matrix is{arr1}")
det_arr1=linalg.det(arr1)
print(round(det_arr1))
arr2=[[3,7],[2,5]]
arr2_inv=linalg.inv(arr2)
print(arr2_inv)
# Out:
# can do it
# the matrix is[[50 29 33]
#  [30 44 12]
#  [ 2  3 78]]
# 102702
# [[ 5. -7.]
#  [-2.  3.]]

# %%
import pandas as pd
data= pd.read_csv(r'C:\Vina\test.csv')
data.dtypes
# Out:
# ORDERNUMBER          int64
# QUANTITYORDERED    float64
# rest                object
# ORDERLINENUMBER      int64
# valid                int64
# Rating               int64
# order_date          object
# dtype: object

# %%
data['rest']
# Out:
# 0     95.70%
# 1     81.35%
# 2     94.74%
# 3     83.26%
# 4       100%
# 5     96.66%
# 6     86.13%
# 7       100%
# 8     98.57%
# 9       100%
# 10      100%
# 11      100%
# 12      100%
# 13      100%
# Name: rest, dtype: object

# %%
data['rest'].sum()
data['rest']= data['rest'].str.strip('%')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data['rest'].sum()
#       2 data['rest']= data['rest'].str.strip('%')
#
# NameError: name 'data' is not defined

# %%
data['rest']
# Out:
# 0     95.70%
# 1     81.35%
# 2     94.74%
# 3     83.26%
# 4       100%
# 5     96.66%
# 6     86.13%
# 7       100%
# 8     98.57%
# 9       100%
# 10      100%
# 11      100%
# 12      100%
# 13      100%
# Name: rest, dtype: object

# %%
import pandas as pd
data= pd.read_csv(r'C:\Vina\test.csv')

# %%
print(data)
# Out:
#     ORDERNUMBER  QUANTITYORDERED    rest  ORDERLINENUMBER  valid  Rating   \
# 0         10107             30.0  95.70%                2      1        1
# 1         10121             34.0  81.35%                5      2        2
# 2         10134             41.0  94.74%                2      3        3
# 3         10145             45.0  83.26%                6      3        3
# 4         10159             49.0    100%               14      4        4
# 5         10168             36.0  96.66%                1      4        4
# 6         10180              NaN  86.13%                9      4        4
# 7         10188             48.0    100%                1      4        4
# 8         10201             22.0  98.57%                2      4        4
# 9         10211              NaN    100%               14      1        5
# 10        10223             37.0    100%                1      1        1
# 11        10237             23.0    100%                7      2        2
# ...

# %%
data['  '].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ORDERLINENUMBER  '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 data['ORDERLINENUMBER  '].sum()
#
# ...

# %%
ORDERLINENUMBER
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 ORDERLINENUMBER
#
# NameError: name 'ORDERLINENUMBER' is not defined

# %%
data['rest']= data['rest'].str.strip('%')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data['rest']= data['rest'].str.strip('%')
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
data= pd.read_csv(r'C:\Vina\test.csv')

# %%
data['rest']
# Out:
# 0     95.70%
# 1     81.35%
# 2     94.74%
# 3     83.26%
# 4       100%
# 5     96.66%
# 6     86.13%
# 7       100%
# 8     98.57%
# 9       100%
# 10      100%
# 11      100%
# 12      100%
# 13      100%
# Name: rest, dtype: object

# %%
data['rest']=data['rest'].str.strip('%')

# %%
data['rest']
# Out:
# 0     95.70
# 1     81.35
# 2     94.74
# 3     83.26
# 4       100
# 5     96.66
# 6     86.13
# 7       100
# 8     98.57
# 9       100
# 10      100
# 11      100
# 12      100
# 13      100
# Name: rest, dtype: object

# %%
data['rest']=data['rest'].astype('float')
data['rest']
# Out:
# 0      95.70
# 1      81.35
# 2      94.74
# 3      83.26
# 4     100.00
# 5      96.66
# 6      86.13
# 7     100.00
# 8      98.57
# 9     100.00
# 10    100.00
# 11    100.00
# 12    100.00
# 13    100.00
# Name: rest, dtype: float64

# %%
data['rest'].sum()
# Out:
# np.float64(1336.4099999999999)

# %%
sum_column=data['rest'].sum()

# %%
print(sum_column)
# Out:
# 1336.4099999999999

# %%
assert data['rest'].dtype=='float'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'test'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 assert data['test'].dtype=='float'
#
# ...

# %%
assert data['rest'].dtype=='float'

# %%
data['valid '].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'valid '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 data['valid '].describe()
#
# ...

# %%
data['valid'].describe()
# Out:
# count    14.000000
# mean      2.642857
# std       1.215739
# min       1.000000
# 25%       2.000000
# 50%       2.500000
# 75%       4.000000
# max       4.000000
# Name: valid, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.hist(data['Rating '])
plt.title("Averege rating ")

# %%
data1=data[data['Rating ']>5.]
data1
# Out:
#     ORDERNUMBER  QUANTITYORDERED    rest  ORDERLINENUMBER  valid  Rating   \
# 0         10107             30.0   95.70                2      1        1
# 1         10121             34.0   81.35                5      2        2
# 2         10134             41.0   94.74                2      3        3
# 3         10145             45.0   83.26                6      3        3
# 4         10159             49.0  100.00               14      4        4
# 5         10168             36.0   96.66                1      4        4
# 6         10180              NaN   86.13                9      4        4
# 7         10188             48.0  100.00                1      4        4
# 8         10201             22.0   98.57                2      4        4
# 9         10211              NaN  100.00               14      1        5
# 10        10223             37.0  100.00                1      1        1
# 11        10237             23.0  100.00                7      2        2
#
# ...

# %%
data.drop(data[data['Rating ']>5].index,inplace= True)
data
# Out:
#     ORDERNUMBER  QUANTITYORDERED    rest  ORDERLINENUMBER  valid  Rating   \
# 0         10107             30.0   95.70                2      1        1
# 1         10121             34.0   81.35                5      2        2
# 2         10134             41.0   94.74                2      3        3
# 3         10145             45.0   83.26                6      3        3
# 4         10159             49.0  100.00               14      4        4
# 5         10168             36.0   96.66                1      4        4
# 6         10180              NaN   86.13                9      4        4
# 7         10188             48.0  100.00                1      4        4
# 8         10201             22.0   98.57                2      4        4
# 9         10211              NaN  100.00               14      1        5
# 10        10223             37.0  100.00                1      1        1
# 11        10237             23.0  100.00                7      2        2
#
# ...

# %%
data
# Out:
#     ORDERNUMBER  QUANTITYORDERED    rest  ORDERLINENUMBER  valid  Rating   \
# 0         10107             30.0   95.70                2      1        1
# 1         10121             34.0   81.35                5      2        2
# 2         10134             41.0   94.74                2      3        3
# 3         10145             45.0   83.26                6      3        3
# 4         10159             49.0  100.00               14      4        4
# 5         10168             36.0   96.66                1      4        4
# 6         10180              NaN   86.13                9      4        4
# 7         10188             48.0  100.00                1      4        4
# 8         10201             22.0   98.57                2      4        4
# 9         10211              NaN  100.00               14      1        5
# 10        10223             37.0  100.00                1      1        1
# 11        10237             23.0  100.00                7      2        2
#
# ...

# %%
data.drop(data[data['Rating ']>5].index,inplace= False)
data
# Out:
#     ORDERNUMBER  QUANTITYORDERED    rest  ORDERLINENUMBER  valid  Rating   \
# 0         10107             30.0   95.70                2      1        1
# 1         10121             34.0   81.35                5      2        2
# 2         10134             41.0   94.74                2      3        3
# 3         10145             45.0   83.26                6      3        3
# 4         10159             49.0  100.00               14      4        4
# 5         10168             36.0   96.66                1      4        4
# 6         10180              NaN   86.13                9      4        4
# 7         10188             48.0  100.00                1      4        4
# 8         10201             22.0   98.57                2      4        4
# 9         10211              NaN  100.00               14      1        5
# 10        10223             37.0  100.00                1      1        1
# 11        10237             23.0  100.00                7      2        2
#
# ...

# %%
data.drop(data[data['Rating ']>5].index,inplace= False)
data
# Out:
#     ORDERNUMBER  QUANTITYORDERED    rest  ORDERLINENUMBER  valid  Rating   \
# 0         10107             30.0   95.70                2      1        1
# 1         10121             34.0   81.35                5      2        2
# 2         10134             41.0   94.74                2      3        3
# 3         10145             45.0   83.26                6      3        3
# 4         10159             49.0  100.00               14      4        4
# 5         10168             36.0   96.66                1      4        4
# 6         10180              NaN   86.13                9      4        4
# 7         10188             48.0  100.00                1      4        4
# 8         10201             22.0   98.57                2      4        4
# 9         10211              NaN  100.00               14      1        5
# 10        10223             37.0  100.00                1      1        1
# 11        10237             23.0  100.00                7      2        2
#
# ...

# %%
data.loc[data['Rating '].max()<=5
# Out:
#   Cell In[36], line 1
#     data.loc[data['Rating '].max()<=5
#                                      ^
# _IncompleteInputError: incomplete input

# %%
import pandas as pd
data1= pd.read_csv(r'C:\Vina\data1.csv')
data.dtypes
# Out:
# ORDERNUMBER          int64
# QUANTITYORDERED    float64
# rest               float64
# ORDERLINENUMBER      int64
# valid                int64
# Rating               int64
# order_date          object
# dtype: object

# %%
import pandas as pd
data= pd.read_csv(r'C:\Vina\data1.csv')
data
# Out:
#    Duration  Pulse  Maxpulse  Calories Precentage
# 0        60    114       140     415.0        60%
# 1        60    102       127     300.0        60%
# 2        60    100       120     300.0        60%
# 3        60    100       120     300.0        60%
# 4        45    104       129     266.0        45%
# 5        45     90       112     180.1        45%
# 6        60     98       126     286.0        60%
# 7        60    100       122     329.4        60%
# 8        60    111       138     400.0        60%

# %%
duplicate
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
print(duplicate)
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
data[duplicate]
# Out:
#    Duration  Pulse  Maxpulse  Calories Precentage
# 3        60    100       120     300.0        60%

# %%
columns=['Duration','Pulse']
duplicates=data.duplicated(subset=columns,keep =False)
duplicates
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# dtype: bool
