# %%
# %config IPCompleter.greedy=True
import pandas as pd 
df=pd.read_csv(r"C:\Users\Hp\Desktop\corey schafer\data\survey_results_public.csv",index_col='Respondent')
schema_df=pd.read_csv(r"C:\Users\Hp\Desktop\corey schafer\data\survey_results_schema.csv")

# %%
schema_df=pd.read_csv(r"C:\Users\Hp\Desktop\corey schafer\data\survey_results_schema.csv",index_col='Column')

# %%
df.shape
# Out:
# (88883, 84)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88883 entries, 1 to 88863
# Data columns (total 84 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MainBranch              88331 non-null  object
#  1   Hobbyist                88883 non-null  object
#  2   OpenSourcer             88883 non-null  object
#  3   OpenSource              86842 non-null  object
#  4   Employment              87181 non-null  object
#  5   Country                 88751 non-null  object
#  6   Student                 87014 non-null  object
#  7   EdLevel                 86390 non-null  object
#  8   UndergradMajor          75614 non-null  object
#  9   EduOther                84260 non-null  object
#  10  OrgSize                 71791 non-null  object
#  11  DevType                 81335 non-null  object
#  12  YearsCode               87938 non-null  object
#  13  Age1stCode              87634 non-null  object
# ...

# %%
df.head(4)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
# 3                             Never
# 4                             Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
#
# ...

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
schema_df.head(2)
# Out:
#                                                  QuestionText
# Column
# Respondent  Randomized respondent ID number (not in order ...
# MainBranch  Which of the following options best describes ...

# %%
schema_df.loc['Respondent','QuestionText']
# Out:
# 'Randomized respondent ID number (not in order of survey response time)'

# %%
df['Country']
# Out:
# Respondent
# 1                United Kingdom
# 2        Bosnia and Herzegovina
# 3                      Thailand
# 4                 United States
# 5                       Ukraine
#                   ...
# 88377                    Canada
# 88601                       NaN
# 88802                       NaN
# 88816                       NaN
# 88863                     Spain
# Name: Country, Length: 88883, dtype: object

# %%
dict1={'first':['Ahmed','mo','basma'],
       'last':['Sheta','salah','wadi'],
       'email':['A@gmail.com','M@gmail.com','B@gmail.com']  
}

# %%
dict1['email']
# Out:
# ['A@gmail.com', 'M@gmail.com', 'B@gmail.com']

# %%
df1=pd.DataFrame(dict1)

# %%
df1['email']
# Out:
# 0    A@gmail.com
# 1    M@gmail.com
# 2    B@gmail.com
# Name: email, dtype: object

# %%
df1.email
# Out:
# 0    A@gmail.com
# 1    M@gmail.com
# 2    B@gmail.com
# Name: email, dtype: object

# %%
df.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
df['Country'].value_counts()
# Out:
# Country
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Papua New Guinea                        1
# Saint Kitts and Nevis                   1
# Saint Vincent and the Grenadines        1
# Sao Tome and Principe                   1
# Chad                                    1
# Name: count, Length: 179, dtype: int64

# %%
df.loc[1:3,'Hobbyist':'Student']
# Out:
#            Hobbyist              OpenSourcer  \
# Respondent
# 1               Yes                    Never
# 2                No  Less than once per year
# 3               Yes                    Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
# 3                               Employed full-time                Thailand
#
#                    Student
# Respondent
# 1                       No
# 2           Yes, full-time
# 3                       No

# %%
df.loc[[12,14],['Country','Student']]
# Out:
#             Country         Student
# Respondent
# 12           Canada  Yes, full-time
# 14          Germany              No

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.set_index('Respondent',inplace=True)

# %%
df.head(3)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
# 3                             Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# ...

# %%
schema_df.sort_index().loc['CareerSat','QuestionText']
# Out:
# 'Overall, how satisfied are you with your career thus far?'

# %%
df.loc[df['Hobbyist']=='Yes','OpenSource']
# Out:
# Respondent
# 1        The quality of OSS and closed source software ...
# 3        The quality of OSS and closed source software ...
# 5        OSS is, on average, of HIGHER quality than pro...
# 6        The quality of OSS and closed source software ...
# 8        OSS is, on average, of HIGHER quality than pro...
#                                ...
# 87739    OSS is, on average, of HIGHER quality than pro...
# 88182    OSS is, on average, of HIGHER quality than pro...
# 88282    The quality of OSS and closed source software ...
# 88377    The quality of OSS and closed source software ...
# 88863    OSS is, on average, of HIGHER quality than pro...
# Name: OpenSource, Length: 71257, dtype: object

# %%
df.loc[df['Country'].isin(['Egypt','Canda']),'Country']
# Out:
# Respondent
# 290      Egypt
# 372      Egypt
# 601      Egypt
# 687      Egypt
# 1831     Egypt
#          ...
# 7461     Egypt
# 25422    Egypt
# 45575    Egypt
# 46058    Egypt
# 85955    Egypt
# Name: Country, Length: 323, dtype: object

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['LanguageWorkedWith'].str.contains('Python',na=False)
# Out:
# Respondent
# 1         True
# 2         True
# 3        False
# 4         True
# 5         True
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: LanguageWorkedWith, Length: 88883, dtype: bool

# %%
df1.columns=[x.lower() for x in df1.columns]

# %%
df1.rename(columns={'first':'first_name'},inplace=True)

# %%
df1
# Out:
#   first_name   last        email
# 0      Ahmed  Sheta  A@gmail.com
# 1         mo  salah  M@gmail.com
# 2      basma   wadi  B@gmail.com

# %%
df1.loc[1,'last']='eid'

# %%
df1
# Out:
#   first_name   last        email
# 0      Ahmed  Sheta  A@gmail.com
# 1         mo    eid  M@gmail.com
# 2      basma   wadi  B@gmail.com

# %%
df1.loc[0,['first_name','last']]=['ahmed','ismail']

# %%
df1
# Out:
#   first_name    last        email
# 0      ahmed  ismail  A@gmail.com
# 1         mo     eid  M@gmail.com
# 2      basma    wadi  B@gmail.com

# %%
df1.at[0,'last']
# Out:
# 'ismail'

# %%
df1.apply(len,axis=1)
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df1['last'].apply(len)
# Out:
# 0    6
# 1    3
# 2    4
# Name: last, dtype: int64

# %%
df1.apply(lambda x :x.min())
# Out:
# first_name          ahmed
# last                  eid
# email         A@gmail.com
# dtype: object

# %%
df1.map(len)
# Out:
#    first_name  last  email
# 0           5     6     11
# 1           2     3     11
# 2           5     4     11

# %%
df1['last']=df1['last'].replace({'Sheta':'sheta'})

# %%
df1
# Out:
#   first_name    last        email
# 0      ahmed  ismail  A@gmail.com
# 1         mo     eid  M@gmail.com
# 2      basma    wadi  B@gmail.com

# %%
df1['phone']=['011292922','0191288338','011928383']

# %%
df1
# Out:
#   first_name    last        email       phone
# 0      ahmed  ismail  A@gmail.com   011292922
# 1         mo     eid  M@gmail.com  0191288338
# 2      basma    wadi  B@gmail.com   011928383

# %%
df1.drop(columns='phone',inplace=True)

# %%
#df1['full_name']=df1['first'] + " "+df1['last']

# %%
df1
# Out:
#   first_name    last        email
# 0      ahmed  ismail  A@gmail.com
# 1         mo     eid  M@gmail.com
# 2      basma    wadi  B@gmail.com

# %%
df1
# Out:
#   first_name    last        email
# 0      ahmed  ismail  A@gmail.com
# 1         mo     eid  M@gmail.com
# 2      basma    wadi  B@gmail.com

# %%
dict2={'first':['Ali'],'last':['karim']}
df3=pd.DataFrame(dict2)

# %%
pd.concat([df1,df3],ignore_index=True)
# Out:
#   first_name    last        email first
# 0      ahmed  ismail  A@gmail.com   NaN
# 1         mo     eid  M@gmail.com   NaN
# 2      basma    wadi  B@gmail.com   NaN
# 3        NaN   karim          NaN   Ali

# %%
#df1.reset_index('first_name',inplace=True)

# %%
df1
# Out:
#   first_name    last        email
# 0      ahmed  ismail  A@gmail.com
# 1         mo     eid  M@gmail.com
# 2      basma    wadi  B@gmail.com

# %%
#df1.drop(index='basma')

# %%
df1
# Out:
#   first_name    last        email
# 0      ahmed  ismail  A@gmail.com
# 1         mo     eid  M@gmail.com
# 2      basma    wadi  B@gmail.com

# %%
df1.sort_values(['first_name'],ascending=False)
# Out:
#   first_name    last        email
# 1         mo     eid  M@gmail.com
# 2      basma    wadi  B@gmail.com
# 0      ahmed  ismail  A@gmail.com

# %%
df.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
df.nlargest(10,'ConvertedComp')['ConvertedComp']
# Out:
# Respondent
# 58      2000000.0
# 102     2000000.0
# 166     2000000.0
# 436     2000000.0
# 452     2000000.0
# 491     2000000.0
# 539     2000000.0
# 770     2000000.0
# 789     2000000.0
# 1232    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.groupby('Country')['ConvertedComp'].agg(['mean','max'])
# Out:
#                                                mean        max
# Country
# Afghanistan                           101953.333333  1000000.0
# Albania                                21833.700000   187668.0
# Algeria                                34924.047619  1000000.0
# Andorra                               160931.000000   171862.0
# Angola                                  7764.000000     7764.0
# ...                                             ...        ...
# Venezuela, Bolivarian Republic of...   14581.627907   137484.0
# Viet Nam                               17233.436782   140000.0
# Yemen                                  16909.166667    60000.0
# Zambia                                 10075.375000    40524.0
# Zimbabwe                               34046.666667   180000.0
#
# [179 rows x 2 columns]

# %%
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df.value_counts('Country',normalize=True)
# Out:
# Country
# United States            0.236042
# India                    0.102095
# Germany                  0.066095
# United Kingdom           0.064642
# Canada                   0.038253
#                            ...
# North Korea              0.000011
# Papua New Guinea         0.000011
# Saint Kitts and Nevis    0.000011
# Tonga                    0.000011
# Timor-Leste              0.000011
# Name: proportion, Length: 179, dtype: float64

# %%
w=df.groupby('Country')['LanguageWorkedWith'].apply(lambda x :x.str.contains('Python').sum())

# %%
df.groupby('Country')['LanguageWorkedWith']

# %%
((w/df.value_counts('Country'))*100).loc['Egypt']
# Out:
# np.float64(34.36532507739938)

# %%
import numpy as np
type(np.nan)
# Out:
# float

# %%
type(None)
# Out:
# NoneType

# %%
import numpy as np
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}
df6=pd.DataFrame(people)

# %%
df6
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df6.dropna(subset=['first','email'],how='all')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df6.dropna()
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df6.replace({'NA':np.nan,'Missing':np.nan},inplace=True)

# %%
df6.dropna()
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
df6.dropna()
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
df6.isnull().sum()
# Out:
# first    3
# last     3
# email    3
# age      3
# dtype: int64

# %%
df6
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df6.fillna(0,inplace=True)
df6['age'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[436], line 2
#       1 df6.fillna(0,inplace=True)
# ----> 2 df6['age'].mean()
#
# File D:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File D:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
# ...

# %%
df6
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63
# 3  Chris  Schafer                        0  36
# 4      0        0                        0   0
# 5      0        0      Anonymous@email.com   0
# 6      0        0                        0   0

# %%
df6['age']=df6['age'].astype(float)
df6['age'].mean()
# Out:
# np.float64(26.714285714285715)

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   first   7 non-null      object
#  1   last    7 non-null      object
#  2   email   7 non-null      object
#  3   age     7 non-null      object
# dtypes: object(4)
# memory usage: 356.0+ bytes

# %%
df['Country'].unique()
# Out:
# array(['United Kingdom', 'Bosnia and Herzegovina', 'Thailand',
#        'United States', 'Ukraine', 'Canada', 'India', 'New Zealand',
#        'Antigua and Barbuda', 'Germany', 'Australia',
#        'Russian Federation', 'Brazil', 'Lithuania', 'Israel',
#        'South Africa', 'Colombia', 'Turkey', 'Switzerland', 'Argentina',
#        'Sri Lanka', 'Czech Republic', 'Denmark', 'Malaysia', 'Bangladesh',
#        'Spain', 'Serbia', 'Poland', 'Sweden', 'China', 'France',
#        'Netherlands', 'Italy', 'Philippines', 'Ireland', 'Pakistan',
#        'Azerbaijan', 'Austria', 'Estonia', 'Croatia', 'South Korea',
#        'Greece', 'Japan', 'Romania', 'Finland', 'Bulgaria', 'Viet Nam',
#        'Slovenia', 'Iran', 'Belarus', 'Hungary', 'Latvia',
#        'Hong Kong (S.A.R.)', 'United Arab Emirates', 'Portugal',
#        'Nigeria', 'Norway', 'Nicaragua', 'Zimbabwe', 'Egypt', 'Mexico',
#        'Dominican Republic', 'Guatemala', 'Chile', 'Ecuador', 'Ghana',
# ...
