# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 x=['1','2','3','4']
# ----> 2 x.dtype()
#
# AttributeError: 'list' object has no attribute 'dtype'

# %%
import pandas as pd

# %%
type(pd.to_numeric(x))
# Out:
# numpy.ndarray

# %%
type
