# %%
from videos.walkthroughs import walkthrough_11 as walkthrough
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from videos.walkthroughs import walkthrough_11 as walkthrough
#
# ModuleNotFoundError: No module named 'videos'
