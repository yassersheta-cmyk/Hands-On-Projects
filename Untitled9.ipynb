# %%
import pandas as pd
import os
from skimage.io import imread
from skimag.transform import resize
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       2 import os
#       3 from skimage.io import imread
# ----> 4 from skimag.transform import resize
#
# ModuleNotFoundError: No module named 'skimag'

# %%
for i in catigories
